# %% [markdown]
# ### Ejercicio 1

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Cargamos el DataFrame

# %%
air_df = pd.read_csv('C:/Users/user1/Downloads/archive/DelayedFlights.csv')

# %% [markdown]
# Visualizamos una variable categórica

# %%
plt.plot(air_df.UniqueCarrier)
plt.show()

# %%
plt.plot(air_df.ArrDelay)
plt.show()
